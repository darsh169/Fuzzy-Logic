# %%
import skfuzzy as fuzz
import numpy as np
from skfuzzy import control as ctrl

# %%
# !python--version
# Out:
# 'python--version' is not recognized as an internal or external command,
# operable program or batch file.

# %%
uni1=np.arange(0,11,1)

# %%
quality=ctrl.Antecedent(np.arange(0,11,1),'quality')
service=ctrl.Antecedent(np.arange(0,11,1),'service')
tip=ctrl.Consequent(np.arange(0,26,1),'tip')

# %%
quality.automf(3)
service.automf(3)

# %%
quality.view()
service.view()
# Out:
# E:\programs\anaconda\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
tip['low']=fuzz.trimf(tip.universe,[0,0,13])
tip['medium']=fuzz.trimf(tip.universe,[0,13,25])
tip['high']=fuzz.trimf(tip.universe,[13,25,25])
tip.view()

# %%
rule1=ctrl.Rule(quality['poor'] |service['poor'],tip['low'])
rule2=ctrl.Rule(service['average'],(tip['medium'],tip['high']))
rule3=ctrl.Rule(service['good']|quality['good'],tip['high'])
rule1.view()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x132e32ec048>)

# %%
tipping_ct=ctrl.ControlSystem([rule1 , rule2 , rule3])

# %%
tip1=ctrl.ControlSystemSimulation(tipping_ct)

# %%
tip1.input['quality']=6.5
tip1.input['service']=9.8

# %%
tip1.compute()
print(tip1.output['tip'])
# Out:
# 19.847607361963192

# %%
help(fuzz)
# Out:
# Help on package skfuzzy:
#
# NAME
#     skfuzzy - scikit-fuzzy (a.k.a. `skfuzzy`): Fuzzy Logic Toolbox for Python.
#
# DESCRIPTION
#     This package implements many useful tools and functions for computation and
#     projects involving fuzzy logic, also known as grey logic.
#
#     Most of the functionality is actually located in subpackages, but like numpy we
#     bring most of the core functionality into the base namespace.
#
#     Recommended Use
#     ---------------
#     >>> import skfuzzy as fuzz
#
# PACKAGE CONTENTS
#     cluster (package)
#     control (package)
#     defuzzify (package)
#     filters (package)
#     fuzzymath (package)
#     image (package)
#     intervals (package)
#     membership (package)
#
# SUBMODULES
#     _cluster
#     _defuzz
#     _filters
#     _fuzzymath
#     _image
#     _intervals
#     _membership
#
# FUNCTIONS
#     addval(interval1, interval2)
#         Add intervals interval1 and interval2.
#
#         Parameters
#         ----------
# ...

# %%
help(tip['low'])
# Out:
# Help on Term in module skfuzzy.control.term object:
#
# class Term(TermPrimitive)
#  |  Term(label, membership_function)
#  |
#  |  A Term is a universe and associated specific membership function.
#  |
#  |  For example, if one were creating a FuzzyVariable with a simple three-
#  |  point liker scale, three `Term` would be created named poor, average,
#  |  and good.
#  |
#  |  Method resolution order:
#  |      Term
#  |      TermPrimitive
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, label, membership_function)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __mod__(self, other)
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  view(self, *args, **kwargs)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  cuts
#  |
#  |  full_label
#  |      Term with parent.  Ex: velocity['fast']
#  |
#  |  membership_value
# ...

# %%
r=tip['low'].__invert__()

# %%
help(r)
# Out:
# Help on TermAggregate in module skfuzzy.control.term object:
#
# class TermAggregate(TermPrimitive)
#  |  TermAggregate(term1, term2, kind)
#  |
#  |  Used to track the creation of AND and OR clauses used when building
#  |  the antecedent of a rule.
#  |
#  |  Method resolution order:
#  |      TermAggregate
#  |      TermPrimitive
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, term1, term2, kind)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  agg_methods
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from TermPrimitive:
#  |
#  |  __and__(self, other)
#  |
#  |  __invert__(self)
#  |
#  |  __or__(self, other)
#  |
#  |  membership_value(self)
#  |
# ...

# %%
quality={'low':fuzz.trimf(uni1,[0,0,5]),'medium':fuzz.trimf(uni1,[0,5,10]),'high':fuzz.trimf(uni1,[5,10,10])}

# %%
service={'low':fuzz.trimf(uni1,[0,0,5]),'medium':fuzz.trimf(uni1,[0,5,10]),'high':fuzz.trimf(uni1,[5,10,10])}

# %%
min(2,5)
# Out:
# 2

# %%
tip_low=[]
tip_med=[]
tip_high=[]

# %%
ow=[1,2]
low=max(ow)

# %%
low
# Out:
# 2

# %%
x=6
y=9

# %%
def or_fun(a,x,b,y,c):
    c.append(max(a[x],b[y]))
    return max(a[x],b[y])

# %%
def and_fun(a,x,b,y,c):
    c.append(min(a[x],b[y]))
    return min(a[x],b[y])

# %%
def cal(a,x,c):
    c.append(a[x])
    return a[x]

# %%
rule1=or_fun(quality['low'],x,service['low'],y,tip_low)

# %%
rule1

# %%
tip_low
# Out:
# [0.0, 0.0]

# %%
quality['low'][6]
# Out:
# 0.0

# %%
service['low'][9]
# Out:
# 0.0
